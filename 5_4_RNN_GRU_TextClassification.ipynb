# %%
import os
import json
import gdown
import numpy as np

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.dataset import random_split
from torchtext.data.functional import to_map_style_dataset
from torchtext import data
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator

from tqdm.notebook import tqdm

import spacy

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Exploring the data

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
train_dict = json.load(open('./train.json', 'r'))
print('Number of train data: ', len(train_dict))
print('Example Data: \n', train_dict[0])

valid_dict = json.load(open('./valid.json', 'r'))
print('\nNumber of valid data: ', len(valid_dict))
print('Example Data: \n', valid_dict[0])

test_dict = json.load(open('./test.json', 'r'))
print('\nNumber of test data: ', len(test_dict))
print('Example Data: \n', test_dict[0])
# Out:
# Number of train data:  5156
# Example Data:
#  {'user_id': 0, 'sentence': 'one of my top priorities here at is making sure that the world prioritizes scaling clean technology innovation here is the message i delivered to world leaders earlier today'}
#
# Number of valid data:  800
# Example Data:
#  {'user_id': 0, 'sentence': 'i got arrested beaten left bloody and unconscious but i havent given up and you can not give up an inspiring read from civil rights legend'}
#
# Number of test data:  800
# Example Data:
#  {'sentence': 'i got arrested beaten left bloody and unconscious but i havent given up and you can not give up an inspiring read from civil rights legend'}

# %%
print(train_dict[0])
# Out:
# {'user_id': 0, 'sentence': 'one of my top priorities here at is making sure that the world prioritizes scaling clean technology innovation here is the message i delivered to world leaders earlier today'}

# %%
ids = []
count_sen = {}
count = 0
for data in train_dict:
    if data['user_id'] not in ids:
        count_sen.update({data['user_id']: 0})
        ids.append(data['user_id'])
    else:
        count_sen[data['user_id']] += 1
print(ids)
print(count_sen)
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]
# {0: 660, 1: 645, 2: 647, 3: 632, 4: 641, 5: 633, 6: 658, 7: 632}

# %%
meta = json.load(open('./meta.json', 'r'))
print(meta.keys())
print(len(meta['tokens']))
print(meta['num_user'])
# Out:
# dict_keys(['tokens', 'num_user'])
# 13369
# 8

# %% [markdown]
# # Pre-processing with spacy

# %%
# tokenizer
spacy_en = spacy.load('en_core_web_sm')

# %%
def tokenize(en_text):
    return [tok.text for tok in spacy_en.tokenizer(en_text)]

def tokenize_with_filtering(en_text):
    # eliminate stop_words
    stop_words = spacy.lang.en.stop_words.STOP_WORDS
    # stop_words = ['the', 'an', 'a']
    filtered = []
    tokenized = [tok.text for tok in spacy_en.tokenizer(en_text)]
    for word in tokenized:
        if word not in stop_words:
            filtered.append(word)
    return filtered

# %%
# example
ex_sen = train_dict[0]['sentence']
print(ex_sen)
print('normal tokenizing: ', tokenize(ex_sen))
print('filtered tokens: ', tokenize_with_filtering(ex_sen))
print(len(tokenize(train_dict[0]['sentence'])))
print(len(train_dict))
print('max sequence length: ', max(len(tokenize(train_dict[i]['sentence'])) for i in range(len(train_dict))))
# Out:
# one of my top priorities here at is making sure that the world prioritizes scaling clean technology innovation here is the message i delivered to world leaders earlier today
# normal tokenizing:  ['one', 'of', 'my', 'top', 'priorities', 'here', 'at', 'is', 'making', 'sure', 'that', 'the', 'world', 'prioritizes', 'scaling', 'clean', 'technology', 'innovation', 'here', 'is', 'the', 'message', 'i', 'delivered', 'to', 'world', 'leaders', 'earlier', 'today']
# filtered tokens:  ['priorities', 'making', 'sure', 'world', 'prioritizes', 'scaling', 'clean', 'technology', 'innovation', 'message', 'delivered', 'world', 'leaders', 'earlier', 'today']
# 29
# 5156
# max sequence length:  62

# %%
train_list = []
valid_list = []
test_list = []
for data in train_dict:
    filtered_sentence = ''
    for word in tokenize_with_filtering(data['sentence']):
        filtered_sentence += word + ' '
    filtered_sentence = filtered_sentence[:-1]
    train_list.append([data['user_id'], filtered_sentence])

for data in valid_dict:
    filtered_sentence = ''
    for word in tokenize_with_filtering(data['sentence']):
        filtered_sentence += word + ' '
    filtered_sentence = filtered_sentence[:-1]
    valid_list.append([data['user_id'], filtered_sentence])

for data in test_dict:
    filtered_sentence = ''
    for word in tokenize_with_filtering(data['sentence']):
        filtered_sentence += word + ' '
    filtered_sentence = filtered_sentence[:-1]
    test_list.append([filtered_sentence])

print(train_list[0])
print(valid_list[0])
print(test_list[0])
# Out:
# [0, 'priorities making sure world prioritizes scaling clean technology innovation message delivered world leaders earlier today']
# [0, 'got arrested beaten left bloody unconscious nt given inspiring read civil rights legend']
# ['got arrested beaten left bloody unconscious nt given inspiring read civil rights legend']

# %% [markdown]
# # Tokenize with torchtext

# %%
tokenizer = get_tokenizer(tokenizer='spacy', language='en_core_web_sm')

# example
print(tokenizer(train_dict[0]['sentence']))
print(len(tokenizer(train_dict[0]['sentence'])))
# Out:
# ['one', 'of', 'my', 'top', 'priorities', 'here', 'at', 'is', 'making', 'sure', 'that', 'the', 'world', 'prioritizes', 'scaling', 'clean', 'technology', 'innovation', 'here', 'is', 'the', 'message', 'i', 'delivered', 'to', 'world', 'leaders', 'earlier', 'today']
# 29

# %%
def yield_tokens(data_iter):
    for text in data_iter:
        yield tokenizer(text)

# %%
vocab = build_vocab_from_iterator(yield_tokens(meta["tokens"]), specials=["<unk>"])
vocab.set_default_index(vocab["<unk>"])

# example
print(vocab(['here', 'is', 'an', 'example']))
# Out:
# [5480, 25, 516, 4057]

# %%
text_pipeline = lambda x: vocab(tokenizer(x))
label_pipeline = lambda x: int(x)

print(text_pipeline(train_dict[0]['sentence']))
print(label_pipeline(train_dict[0]['user_id']))
# Out:
# [8328, 8243, 7817, 12049, 9223, 5480, 814, 25, 7163, 11509, 31, 11848, 13143, 9226, 10363, 2108, 11752, 6014, 5480, 25, 11848, 7458, 5, 3003, 12005, 13143, 6744, 3584, 12008]
# 0

# %%
word_to_idx = {word[0] : i + 2 for i, word in enumerate(train_dict)} # 0, 1 index will be used for other purposes
word_to_idx['pad'] = 1 # index 1
word_to_idx['unk'] = 0 # index 0

encoded = []
for i in range(len(train_data)):
    token = tokenize_with_filtering(train_data[i]['sentence'])
    temp = []
    for word in token:
        try:
            temp.append(word_to_idx[word])
        except KeyError:
            temp.append(word_to_idx['unk'])
    encoded.append(temp)
print(encoded)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 word_to_idx = {word[0] : i + 2 for i, word in enumerate()} # 0, 1 index will be used for other purposes
#       2 word_to_idx['pad'] = 1 # index 1
#       3 word_to_idx['unk'] = 0 # index 0
#
# TypeError: enumerate() missing required argument 'iterable' (pos 1)

# %%
import torch
from torchtext import data

sentences = data.Field(tokenize = 'spacy', tokenizer_language = 'en')
label = data.LabelField(dtype = torch.float)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[62], line 2
#       1 import torch
# ----> 2 from torchtext import data
#       4 sentences = data.Field(tokenize = 'spacy', tokenizer_language = 'en')
#       5 label = data.LabelField(dtype = torch.float)
#
# ModuleNotFoundError: No module named 'torchtext'

# %% [markdown]
# # Define Models

# %% [markdown]
# ## RNN

# %%
def collate_batch(batch):
    label_list, text_list, offsets = [], [], [0]
    for (_label, _text) in batch:
        label_list.append(label_pipeline(_label))
        processed_text = torch.tensor(text_pipeline(_text), dtype=torch.int64)
        text_list.append(processed_text)
        offsets.append(processed_text.size(0))
    label_list = torch.tensor(label_list, dtype=torch.int64)
    offsets = torch.tensor(offsets[:-1]).cumsum(dim=0)
    text_list = torch.cat(text_list)
    return label_list.to(device), text_list.to(device), offsets.to(device)

# %%
class TextClassificationModel(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, num_layers, num_class):
        super(TextClassificationModel, self).__init__()
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.num_class = num_class
        
        self.embedding = nn.EmbeddingBag(self.vocab_size, self.embed_dim, sparse=True)
        self.rnn = nn.RNN(self.embed_dim, self.hidden_dim, self.num_layers, batch_first=True)
        
        self.fc = nn.Linear(self.hidden_dim, self.num_class)
        
        self.dropout = nn.Dropout(0.4)
        self.layernorm1 = nn.LayerNorm([batch_size, 1, embed_dim])
        
        self.init_weights()
    
    def init_weights(self):
        initrange = 0.5
        self.embedding.weight.data.uniform_(-initrange, initrange)
        self.fc.weight.data.uniform_(-initrange, initrange)
        self.fc.bias.data.zero_()
        
    def forward(self, text, offsets):
        # print('embedding shape before view: ', self.embedding(text, offsets).shape)
        embedded = self.embedding(text, offsets).view(batch_size, -1, self.embed_dim)
        # print('embedding shape after view:', embedded.shape)
        embedded = self.layernorm1(self.dropout(embedded))
        
        hidden = torch.zeros(
        self.num_layers, embedded.size(0), self.hidden_dim).to(device)
        
        rnn_out, hidden = self.rnn(embedded, hidden)
        
        out = self.fc(rnn_out[:, -1:]).view([-1, self.num_class])
        return out

# %%
train_iter = train_list
num_class = len(set([label for (label, text) in train_iter]))
vocab_size = len(vocab)
emsize = 128
hiddim = 32
num_layers = 1

model = TextClassificationModel(vocab_size, emsize, hiddim, num_layers, num_class).to(device)
print(num_class, vocab_size)
print(model)
# Out:
# 8 13333
# TextClassificationModel(
#   (embedding): EmbeddingBag(13333, 128, mode=mean)
#   (rnn): RNN(128, 32, batch_first=True)
#   (fc): Linear(in_features=32, out_features=8, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
#   (layernorm1): LayerNorm((1, 1, 128), eps=1e-05, elementwise_affine=True)
# )

# %%
def get_n_params(model):
    pp=0
    for p in list(model.parameters()):
        nn=1
        for s in list(p.size()):
            nn = nn * s
        pp += nn
    return pp

# %%
get_n_params(model)
# Out:
# 1712328

# %% [markdown]
# ### Training, evaluation functions

# %%
# training function (for RNN)
def train(dataloader):
    model.train()
    total_acc, total_count = 0, 0
    log_interval = 500
    
    for idx, (label, text, offsets) in enumerate(dataloader):
        optimizer.zero_grad()
        predicted_label = model(text, offsets)
        loss = criterion(predicted_label, label)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.1)
        optimizer.step()
        total_acc += (predicted_label.argmax(1) == label).sum().item()
        total_count += label.size(0)
        if idx % log_interval == 0 and idx > 0:
            print('| epoch {:3d} | {:5d}/{:5d} batches | accuracy {:8.3f}'
                  .format(epoch, idx, len(dataloader), total_acc/total_count))
            total_acc, total_count = 0, 0

# %%
# evaluation function (for RNN)
def evaluate(dataloader):
    model.eval()
    total_acc, total_count = 0, 0
    
    with torch.no_grad():
        for idx, (label, text, offsets) in enumerate(dataloader):
            predicted_label = model(text, offsets)
            loss = criterion(predicted_label, label)
            total_acc += (predicted_label.argmax(1) == label).sum().item()
            total_count += label.size(0)
    return total_acc/total_count

def evaluate_pred(dataloader):
    model.eval()
    total_acc, total_count = 0, 0
    
    with torch.no_grad():
        for idx, (label, text, offsets) in enumerate(dataloader):
            predicted_label = model(text, offsets)
            loss = criterion(predicted_label, label)
            total_acc += (predicted_label.argmax(1) == label).sum().item()
            total_count += label.size(0)

    return total_acc/total_count

# %% [markdown]
# ## GRU

# %%
class TextClassificationGRU(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, num_layers, num_class):
        super(TextClassificationGRU, self).__init__()
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.num_class = num_class
        
        self.embedding = nn.EmbeddingBag(self.vocab_size, self.embed_dim, sparse=True)
        self.gru = nn.GRU(self.embed_dim, self.hidden_dim, self.num_layers, batch_first=True)
        
        self.fc = nn.Linear(self.hidden_dim, self.num_class)
        
        self.dropout = nn.Dropout(0.4)
        self.layernorm1 = nn.LayerNorm([batch_size, 1, embed_dim])
        
        self.init_weights()
    
    def init_weights(self):
        initrange = 0.5
        self.embedding.weight.data.uniform_(-initrange, initrange)
        self.fc.weight.data.uniform_(-initrange, initrange)
        self.fc.bias.data.zero_()
        
    def forward(self, text, offsets):
        embedded = self.embedding(text, offsets).view(batch_size, -1, self.embed_dim)
        embedded = self.dropout(embedded)
        embedded = self.layernorm1(embedded)
        
        hidden = torch.zeros(
        self.num_layers, embedded.size(0), self.hidden_dim).to(device)
        
        gru_out, hidden = self.gru(embedded, hidden)
        
        out = self.fc(gru_out[:, -1:]).view([-1, self.num_class])
        return out

# %%
train_iter = train_list
num_class = len(set([label for (label, text) in train_iter]))
vocab_size = len(vocab)
emsize = 128
hiddim = 32
num_layers = 1

model = TextClassificationGRU(vocab_size, emsize, hiddim, num_layers, num_class).to(device)
print(num_class, vocab_size)
print(model)
# Out:
# 8 13333
# TextClassificationGRU(
#   (embedding): EmbeddingBag(13333, 128, mode=mean)
#   (gru): GRU(128, 32, batch_first=True)
#   (fc): Linear(in_features=32, out_features=8, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
#   (layernorm1): LayerNorm((1, 1, 128), eps=1e-05, elementwise_affine=True)
# )

# %%
get_n_params(model)
# Out:
# 1722696

# %%
class TextClassificationLSTM(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, num_layers, num_class):
        super(TextClassificationLSTM, self).__init__()
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.num_class = num_class
        
        self.embedding = nn.EmbeddingBag(self.vocab_size, self.embed_dim, sparse=True)
        self.lstm = nn.LSTM(self.embed_dim, self.hidden_dim, self.num_layers, batch_first=True)
        
        self.fc = nn.Linear(self.hidden_dim, self.num_class)
        
        self.dropout = nn.Dropout(0.4)
        self.layernorm1 = nn.LayerNorm([batch_size, 1, embed_dim])
        
        self.init_weights()
    
    def init_weights(self):
        initrange = 0.5
        self.embedding.weight.data.uniform_(-initrange, initrange)
        self.fc.weight.data.uniform_(-initrange, initrange)
        self.fc.bias.data.zero_()
        
    def forward(self, text, offsets):
        embedded = self.embedding(text, offsets).view(batch_size, -1, self.embed_dim)
        embedded = self.dropout(embedded)
        embedded = self.layernorm1(embedded)
        
        hidden = torch.zeros(
        self.num_layers, embedded.size(0), self.hidden_dim).to(device)
        
        lstm_out = self.lstm(embedded, hidden)
        
        out = self.fc(rnn_out[:, -1:]).view([-1, self.num_class])
        return out

# %%
train_iter = train_list
num_class = len(set([label for (label, text) in train_iter]))
vocab_size = len(vocab)
emsize = 128
hiddim = 32
num_layers = 1

model = TextClassificationLSTM(vocab_size, emsize, hiddim, num_layers, num_class).to(device)
print(num_class, vocab_size)
print(model)
# Out:
# 8 13370
# TextClassificationLSTM(
#   (embedding): EmbeddingBag(13370, 128, mode=mean)
#   (lstm): LSTM(128, 32, batch_first=True)
#   (fc): Linear(in_features=32, out_features=8, bias=True)
#   (dropout): Dropout(p=0.4, inplace=False)
#   (layernorm1): LayerNorm((1, 1, 128), eps=1e-05, elementwise_affine=True)
# )

# %%
get_n_params(model)
# Out:
# 1732616

# %% [markdown]
# # Train, Eval

# %%
# Hyperparameters
epochs = 20
lr = 5
batch_size = 1

criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.95)

total_accu = None

# split train, valid, test
train_iter, test_iter = train_list, valid_list

train_dataset = to_map_style_dataset(train_iter)
test_dataset = to_map_style_dataset(test_iter)

num_train = int(len(train_dataset) * 0.95)

split_train_, split_valid_ = \
    random_split(train_dataset, [num_train, len(train_dataset) - num_train])

train_dataloader = DataLoader(split_train_, batch_size=batch_size,
                              shuffle=True, collate_fn=collate_batch)
valid_dataloader = DataLoader(split_valid_, batch_size=batch_size,
                              shuffle=True, collate_fn=collate_batch)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size,
                             shuffle=True, collate_fn=collate_batch)

# split train, valid
# train_iter = train_list
# valid_iter = valid_list

# train_dataset = to_map_style_dataset(train_iter)
# valid_dataset = to_map_style_dataset(valid_iter)

# train_dataloader = DataLoader(train_dataset, batch_size=batch_size,
#                              shuffle=True, collate_fn=collate_batch)
# valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size,
#                              shuffle=True, collate_fn=collate_batch)

for epoch in range(1, epochs + 1):
    train(train_dataloader)
    accu_val = evaluate(valid_dataloader)
    if total_accu is not None and total_accu > accu_val:
        scheduler.step()
    else:
        total_accu = accu_val
    print('-' * 59)
    print('| end of epoch {:3d} | valid accuracy {:8.3f} '
          .format(epoch, accu_val))
    print('-' * 59)
    model_path = './saved_models/221221_FT_RNN_SGD_DO_LN_5_v1/'
    if not os.path.isdir(model_path):
        os.mkdir(model_path)
    torch.save(model.state_dict(), os.path.join(model_path, 'epoch_{}.pth'.format(epoch)))
# Out:
# | epoch   1 |   500/ 4898 batches | accuracy    0.194
# | epoch   1 |  1000/ 4898 batches | accuracy    0.232
# | epoch   1 |  1500/ 4898 batches | accuracy    0.324
# | epoch   1 |  2000/ 4898 batches | accuracy    0.342
# | epoch   1 |  2500/ 4898 batches | accuracy    0.362
# | epoch   1 |  3000/ 4898 batches | accuracy    0.360
# | epoch   1 |  3500/ 4898 batches | accuracy    0.454
# | epoch   1 |  4000/ 4898 batches | accuracy    0.454
# | epoch   1 |  4500/ 4898 batches | accuracy    0.464
# -----------------------------------------------------------
# | end of epoch   1 | valid accuracy    0.527
# -----------------------------------------------------------
# | epoch   2 |   500/ 4898 batches | accuracy    0.499
# | epoch   2 |  1000/ 4898 batches | accuracy    0.540
# | epoch   2 |  1500/ 4898 batches | accuracy    0.520
# | epoch   2 |  2000/ 4898 batches | accuracy    0.628
# | epoch   2 |  2500/ 4898 batches | accuracy    0.578
# | epoch   2 |  3000/ 4898 batches | accuracy    0.572
# | epoch   2 |  3500/ 4898 batches | accuracy    0.576
# | epoch   2 |  4000/ 4898 batches | accuracy    0.568
# | epoch   2 |  4500/ 4898 batches | accuracy    0.612
# -----------------------------------------------------------
# | end of epoch   2 | valid accuracy    0.593
# -----------------------------------------------------------
# | epoch   3 |   500/ 4898 batches | accuracy    0.641
# | epoch   3 |  1000/ 4898 batches | accuracy    0.686
# | epoch   3 |  1500/ 4898 batches | accuracy    0.648
# | epoch   3 |  2000/ 4898 batches | accuracy    0.690
# | epoch   3 |  2500/ 4898 batches | accuracy    0.632
# | epoch   3 |  3000/ 4898 batches | accuracy    0.650
# | epoch   3 |  3500/ 4898 batches | accuracy    0.672
# | epoch   3 |  4000/ 4898 batches | accuracy    0.638
# | epoch   3 |  4500/ 4898 batches | accuracy    0.698
# -----------------------------------------------------------
# | end of epoch   3 | valid accuracy    0.647
# -----------------------------------------------------------
# | epoch   4 |   500/ 4898 batches | accuracy    0.693
# | epoch   4 |  1000/ 4898 batches | accuracy    0.738
# | epoch   4 |  1500/ 4898 batches | accuracy    0.742
# | epoch   4 |  2000/ 4898 batches | accuracy    0.712
# | epoch   4 |  2500/ 4898 batches | accuracy    0.702
# | epoch   4 |  3000/ 4898 batches | accuracy    0.736
# | epoch   4 |  3500/ 4898 batches | accuracy    0.734
# | epoch   4 |  4000/ 4898 batches | accuracy    0.766
# | epoch   4 |  4500/ 4898 batches | accuracy    0.728
# -----------------------------------------------------------
# | end of epoch   4 | valid accuracy    0.678
# -----------------------------------------------------------
# | epoch   5 |   500/ 4898 batches | accuracy    0.768
# | epoch   5 |  1000/ 4898 batches | accuracy    0.754
# | epoch   5 |  1500/ 4898 batches | accuracy    0.742
# | epoch   5 |  2000/ 4898 batches | accuracy    0.770
# | epoch   5 |  2500/ 4898 batches | accuracy    0.776
# | epoch   5 |  3000/ 4898 batches | accuracy    0.784
# | epoch   5 |  3500/ 4898 batches | accuracy    0.786
# | epoch   5 |  4000/ 4898 batches | accuracy    0.790
# | epoch   5 |  4500/ 4898 batches | accuracy    0.748
# -----------------------------------------------------------
# | end of epoch   5 | valid accuracy    0.651
# -----------------------------------------------------------
# | epoch   6 |   500/ 4898 batches | accuracy    0.808
# | epoch   6 |  1000/ 4898 batches | accuracy    0.814
# | epoch   6 |  1500/ 4898 batches | accuracy    0.812
# | epoch   6 |  2000/ 4898 batches | accuracy    0.786
# | epoch   6 |  2500/ 4898 batches | accuracy    0.820
# | epoch   6 |  3000/ 4898 batches | accuracy    0.836
# | epoch   6 |  3500/ 4898 batches | accuracy    0.806
# | epoch   6 |  4000/ 4898 batches | accuracy    0.802
# | epoch   6 |  4500/ 4898 batches | accuracy    0.778
# -----------------------------------------------------------
# | end of epoch   6 | valid accuracy    0.640
# -----------------------------------------------------------
# | epoch   7 |   500/ 4898 batches | accuracy    0.846
# | epoch   7 |  1000/ 4898 batches | accuracy    0.792
# | epoch   7 |  1500/ 4898 batches | accuracy    0.838
# | epoch   7 |  2000/ 4898 batches | accuracy    0.840
# | epoch   7 |  2500/ 4898 batches | accuracy    0.832
# | epoch   7 |  3000/ 4898 batches | accuracy    0.830
# | epoch   7 |  3500/ 4898 batches | accuracy    0.842
# | epoch   7 |  4000/ 4898 batches | accuracy    0.854
# | epoch   7 |  4500/ 4898 batches | accuracy    0.826
# -----------------------------------------------------------
# | end of epoch   7 | valid accuracy    0.667
# -----------------------------------------------------------
# | epoch   8 |   500/ 4898 batches | accuracy    0.844
# | epoch   8 |  1000/ 4898 batches | accuracy    0.852
# | epoch   8 |  1500/ 4898 batches | accuracy    0.844
# | epoch   8 |  2000/ 4898 batches | accuracy    0.866
# | epoch   8 |  2500/ 4898 batches | accuracy    0.838
# | epoch   8 |  3000/ 4898 batches | accuracy    0.852
# | epoch   8 |  3500/ 4898 batches | accuracy    0.830
# | epoch   8 |  4000/ 4898 batches | accuracy    0.836
# | epoch   8 |  4500/ 4898 batches | accuracy    0.842
# -----------------------------------------------------------
# | end of epoch   8 | valid accuracy    0.671
# -----------------------------------------------------------
# | epoch   9 |   500/ 4898 batches | accuracy    0.848
# | epoch   9 |  1000/ 4898 batches | accuracy    0.860
# | epoch   9 |  1500/ 4898 batches | accuracy    0.864
# | epoch   9 |  2000/ 4898 batches | accuracy    0.882
# | epoch   9 |  2500/ 4898 batches | accuracy    0.884
# | epoch   9 |  3000/ 4898 batches | accuracy    0.892
# | epoch   9 |  3500/ 4898 batches | accuracy    0.882
# | epoch   9 |  4000/ 4898 batches | accuracy    0.868
# | epoch   9 |  4500/ 4898 batches | accuracy    0.868
# -----------------------------------------------------------
# | end of epoch   9 | valid accuracy    0.674
# -----------------------------------------------------------
# | epoch  10 |   500/ 4898 batches | accuracy    0.918
# | epoch  10 |  1000/ 4898 batches | accuracy    0.868
# | epoch  10 |  1500/ 4898 batches | accuracy    0.872
# | epoch  10 |  2000/ 4898 batches | accuracy    0.870
# | epoch  10 |  2500/ 4898 batches | accuracy    0.872
# | epoch  10 |  3000/ 4898 batches | accuracy    0.900
# | epoch  10 |  3500/ 4898 batches | accuracy    0.880
# | epoch  10 |  4000/ 4898 batches | accuracy    0.872
# | epoch  10 |  4500/ 4898 batches | accuracy    0.892
# -----------------------------------------------------------
# | end of epoch  10 | valid accuracy    0.667
# -----------------------------------------------------------
# | epoch  11 |   500/ 4898 batches | accuracy    0.900
# | epoch  11 |  1000/ 4898 batches | accuracy    0.912
# | epoch  11 |  1500/ 4898 batches | accuracy    0.890
# | epoch  11 |  2000/ 4898 batches | accuracy    0.880
# | epoch  11 |  2500/ 4898 batches | accuracy    0.894
# | epoch  11 |  3000/ 4898 batches | accuracy    0.890
# | epoch  11 |  3500/ 4898 batches | accuracy    0.910
# | epoch  11 |  4000/ 4898 batches | accuracy    0.896
# | epoch  11 |  4500/ 4898 batches | accuracy    0.912
# -----------------------------------------------------------
# | end of epoch  11 | valid accuracy    0.671
# -----------------------------------------------------------
# | epoch  12 |   500/ 4898 batches | accuracy    0.908
# | epoch  12 |  1000/ 4898 batches | accuracy    0.936
# | epoch  12 |  1500/ 4898 batches | accuracy    0.918
# | epoch  12 |  2000/ 4898 batches | accuracy    0.908
# | epoch  12 |  2500/ 4898 batches | accuracy    0.914
# | epoch  12 |  3000/ 4898 batches | accuracy    0.906
# | epoch  12 |  3500/ 4898 batches | accuracy    0.906
# | epoch  12 |  4000/ 4898 batches | accuracy    0.920
# | epoch  12 |  4500/ 4898 batches | accuracy    0.914
# -----------------------------------------------------------
# | end of epoch  12 | valid accuracy    0.674
# -----------------------------------------------------------
# | epoch  13 |   500/ 4898 batches | accuracy    0.918
# | epoch  13 |  1000/ 4898 batches | accuracy    0.924
# | epoch  13 |  1500/ 4898 batches | accuracy    0.900
# | epoch  13 |  2000/ 4898 batches | accuracy    0.928
# | epoch  13 |  2500/ 4898 batches | accuracy    0.928
# | epoch  13 |  3000/ 4898 batches | accuracy    0.894
# | epoch  13 |  3500/ 4898 batches | accuracy    0.914
# | epoch  13 |  4000/ 4898 batches | accuracy    0.946
# | epoch  13 |  4500/ 4898 batches | accuracy    0.928
# -----------------------------------------------------------
# | end of epoch  13 | valid accuracy    0.667
# -----------------------------------------------------------
# | epoch  14 |   500/ 4898 batches | accuracy    0.926
# | epoch  14 |  1000/ 4898 batches | accuracy    0.942
# | epoch  14 |  1500/ 4898 batches | accuracy    0.936
# | epoch  14 |  2000/ 4898 batches | accuracy    0.914
# | epoch  14 |  2500/ 4898 batches | accuracy    0.932
# | epoch  14 |  3000/ 4898 batches | accuracy    0.922
# | epoch  14 |  3500/ 4898 batches | accuracy    0.930
# | epoch  14 |  4000/ 4898 batches | accuracy    0.946
# | epoch  14 |  4500/ 4898 batches | accuracy    0.934
# -----------------------------------------------------------
# | end of epoch  14 | valid accuracy    0.686
# -----------------------------------------------------------
# | epoch  15 |   500/ 4898 batches | accuracy    0.926
# | epoch  15 |  1000/ 4898 batches | accuracy    0.902
# | epoch  15 |  1500/ 4898 batches | accuracy    0.924
# | epoch  15 |  2000/ 4898 batches | accuracy    0.934
# | epoch  15 |  2500/ 4898 batches | accuracy    0.940
# | epoch  15 |  3000/ 4898 batches | accuracy    0.936
# | epoch  15 |  3500/ 4898 batches | accuracy    0.950
# | epoch  15 |  4000/ 4898 batches | accuracy    0.940
# | epoch  15 |  4500/ 4898 batches | accuracy    0.946
# -----------------------------------------------------------
# | end of epoch  15 | valid accuracy    0.671
# -----------------------------------------------------------
# | epoch  16 |   500/ 4898 batches | accuracy    0.948
# | epoch  16 |  1000/ 4898 batches | accuracy    0.932
# | epoch  16 |  1500/ 4898 batches | accuracy    0.946
# | epoch  16 |  2000/ 4898 batches | accuracy    0.940
# | epoch  16 |  2500/ 4898 batches | accuracy    0.932
# | epoch  16 |  3000/ 4898 batches | accuracy    0.928
# | epoch  16 |  3500/ 4898 batches | accuracy    0.924
# | epoch  16 |  4000/ 4898 batches | accuracy    0.954
# | epoch  16 |  4500/ 4898 batches | accuracy    0.930
# -----------------------------------------------------------
# | end of epoch  16 | valid accuracy    0.678
# -----------------------------------------------------------
# | epoch  17 |   500/ 4898 batches | accuracy    0.932
# | epoch  17 |  1000/ 4898 batches | accuracy    0.952
# | epoch  17 |  1500/ 4898 batches | accuracy    0.954
# | epoch  17 |  2000/ 4898 batches | accuracy    0.952
# | epoch  17 |  2500/ 4898 batches | accuracy    0.934
# | epoch  17 |  3000/ 4898 batches | accuracy    0.938
# | epoch  17 |  3500/ 4898 batches | accuracy    0.954
# | epoch  17 |  4000/ 4898 batches | accuracy    0.952
# | epoch  17 |  4500/ 4898 batches | accuracy    0.932
# -----------------------------------------------------------
# | end of epoch  17 | valid accuracy    0.678
# -----------------------------------------------------------
# | epoch  18 |   500/ 4898 batches | accuracy    0.966
# | epoch  18 |  1000/ 4898 batches | accuracy    0.952
# | epoch  18 |  1500/ 4898 batches | accuracy    0.966
# | epoch  18 |  2000/ 4898 batches | accuracy    0.948
# | epoch  18 |  2500/ 4898 batches | accuracy    0.952
# | epoch  18 |  3000/ 4898 batches | accuracy    0.944
# | epoch  18 |  3500/ 4898 batches | accuracy    0.938
# | epoch  18 |  4000/ 4898 batches | accuracy    0.940
# | epoch  18 |  4500/ 4898 batches | accuracy    0.970
# -----------------------------------------------------------
# | end of epoch  18 | valid accuracy    0.671
# -----------------------------------------------------------
# | epoch  19 |   500/ 4898 batches | accuracy    0.958
# | epoch  19 |  1000/ 4898 batches | accuracy    0.954
# | epoch  19 |  1500/ 4898 batches | accuracy    0.954
# | epoch  19 |  2000/ 4898 batches | accuracy    0.950
# | epoch  19 |  2500/ 4898 batches | accuracy    0.950
# | epoch  19 |  3000/ 4898 batches | accuracy    0.938
# | epoch  19 |  3500/ 4898 batches | accuracy    0.944
# | epoch  19 |  4000/ 4898 batches | accuracy    0.972
# | epoch  19 |  4500/ 4898 batches | accuracy    0.956
# -----------------------------------------------------------
# | end of epoch  19 | valid accuracy    0.667
# -----------------------------------------------------------
# | epoch  20 |   500/ 4898 batches | accuracy    0.960
# | epoch  20 |  1000/ 4898 batches | accuracy    0.964
# | epoch  20 |  1500/ 4898 batches | accuracy    0.956
# | epoch  20 |  2000/ 4898 batches | accuracy    0.964
# | epoch  20 |  2500/ 4898 batches | accuracy    0.956
# | epoch  20 |  3000/ 4898 batches | accuracy    0.966
# | epoch  20 |  3500/ 4898 batches | accuracy    0.952
# | epoch  20 |  4000/ 4898 batches | accuracy    0.934
# | epoch  20 |  4500/ 4898 batches | accuracy    0.950
# -----------------------------------------------------------
# | end of epoch  20 | valid accuracy    0.678
# -----------------------------------------------------------

# %%
accu_test = evaluate(test_dataloader)
print('test accuracy {:8.3f}'.format(accu_test))
# Out:
# test accuracy    0.675

# %%
pth_list = os.listdir(model_path)
accu_test_list = []
for file_path in pth_list:
    path = os.path.join(model_path, file_path)
    model.load_state_dict(torch.load(path))
    accu_test_list.append(evaluate(test_dataloader))
print(accu_test_list)
# Out:
# [0.6325, 0.69625, 0.68625, 0.67, 0.6825, 0.65875, 0.69125, 0.48125, 0.685, 0.65125, 0.59875, 0.69125, 0.65375, 0.6975, 0.6975, 0.69, 0.675, 0.57625, 0.63125, 0.6925]

# %%
for idx, accu in enumerate(accu_test_list):
    if max(accu_test_list) == accu:
        print('best epoch: ', idx + 1)
        print('best acc_test: ', max(accu_test_list))
# Out:
# best epoch:  7
# best acc_test:  0.685

# %%
pred = evaluate_pred(test_dataloader)
print('test accuracy {:8.3f}'.format(pred))
# Out:
# test accuracy    0.724

# %%
for i in range(len(valid_dict)):
    print(valid_dict[i])
# Out:
# {'user_id': 0, 'sentence': 'i got arrested beaten left bloody and unconscious but i havent given up and you can not give up an inspiring read from civil rights legend'}
# {'user_id': 0, 'sentence': 'as weve seen this past year new variants of disease can emerge over time in order to develop new tools to fight the disease we need to identify those variants quickly dr senjuti saha is one expert working to sequence sars cov'}
# {'user_id': 0, 'sentence': 'this book written by young surgeon with terminal cancer earned my admirationand tears'}
# {'user_id': 0, 'sentence': 'without access to energy the poor are denied all of the benefits that come with power'}
# {'user_id': 0, 'sentence': 'be catalyst is financing the foundation of clean economy through four critical technologies in these areas catalyst'}
# {'user_id': 0, 'sentence': 'every spring i visit omaha nebraska to catch up with my friend'}
# {'user_id': 0, 'sentence': 'my family loved talking about this book at the dinner table and i think yours will too'}
# {'user_id': 0, 'sentence': 'tune in at am et for my conversation with and more amazing changemakers'}
# {'user_id': 0, 'sentence': 'alzheimers and related dementias have impacted far too many families around the worldincluding my own new funding from will help accelerate data collection and sharing to enable early detection and treatment'}
# {'user_id': 0, 'sentence': 'i was impressed and inspired by the way pete peterson brought together brilliant people to take on tough problems like health care in the and nuclear proliferation around the world i learned lot from pete and will miss him'}
# {'user_id': 0, 'sentence': 'there will be more breakthrough cases in people who are vxd which sounds concerning but is purely factor of how many people are vxd and how fast this variant is spreading vaccines are designed to prevent people from getting seriously ill or dying and are doing that well'}
# {'user_id': 0, 'sentence': 'the decisions we make now will have profound impact on the lives of millions of people'}
# {'user_id': 0, 'sentence': 'covid will not be the last pandemic threat the world faces i spoke to the community about the ambitious innovation agenda we need to end this crisis and be ready to respond to the next'}
# {'user_id': 0, 'sentence': 'michael elliott was tremendous leader and an inspiration to many including me im sad to learn of his death'}
# {'user_id': 0, 'sentence': 'exciting progress this new genetic chip could help bring the benefits of precision medicine to africa'}
# {'user_id': 0, 'sentence': 'tomorrow is day when the world celebrates the progress made by and for women im inspired by ellen johnson sirleaf she was recently awarded the ibrahim prize for achievement in african leadership'}
# {'user_id': 0, 'sentence': 'in small groups of hiv patients in mozambique decided to challenge the traditional approach to hiv treatment this is their story'}
# {'user_id': 0, 'sentence': 'utterly devastated by the news of murder she was remarkable compassionate and brilliant champion of women and girls'}
# {'user_id': 0, 'sentence': 'sleeping sickness is disease most people have never heard of heres what it is and how we can eliminate it'}
# {'user_id': 0, 'sentence': 'progress is not matter of faith or optimism but is fact of human history indeed the greatest fact in human history stirring ted talk from one of my favorite authors'}
# {'user_id': 0, 'sentence': 'vaclav smils books are amazing his latest will give you framework to think about humanity'}
# {'user_id': 0, 'sentence': 'melinda and i are huge fans of this is us so it was real treat for us to see speak at our daughter jenns graduation his message to graduates was simple yet profound do not be afraid to let your light shine'}
# {'user_id': 0, 'sentence': 'if youre getting degree from college this spring i have present for you download free copy of one of my favorite books'}
# {'user_id': 0, 'sentence': 'i really enjoyed this conversation between our foundation ceo and science friday host'}
# {'user_id': 0, 'sentence': 'in entrusted us with the biggest single gift anyone ever gave anybody for anything'}
# {'user_id': 0, 'sentence': 'hajira didnt have the scores to get into most colleges but one school saw her potential'}
# {'user_id': 0, 'sentence': 'promising study new type of probiotic may reduce the risk of sepsis in newborn babies'}
# {'user_id': 0, 'sentence': 'i got to check an item off my bucket list and help great cause too'}
# {'user_id': 0, 'sentence': 'has been leader in its field since its founding years ago this is well deserved prize'}
# {'user_id': 0, 'sentence': 'i visited earlier this year and met an amazing group of students'}
# {'user_id': 0, 'sentence': 'our foundation joined the polio fight almost years ago and in all that time i can not think of more important moment than right now'}
# {'user_id': 0, 'sentence': 'i had blast taping this segment of with kirsty young'}
# {'user_id': 0, 'sentence': 'i appreciate how thoughtful my friend is about how he gives back with every purchase of his new book principles donation will be given to the charity of your choice'}
# {'user_id': 0, 'sentence': 'im deeply saddened to hear of tachis passing i loved working with him and i learned lot from him his passion for saving lives and making the world fairer place was inspiring and he matched it with an incredible intellect i will miss him'}
# {'user_id': 0, 'sentence': 'stopping alzheimers requires more eyes on the problem addi recently hosted their st data challenge i was inspired to see more than people from countries regions join the fight'}
# {'user_id': 0, 'sentence': 'playing tennis with was one of my favorite parts of i cant wait to team up with him again on march th for the next match for africa with and'}
# {'user_id': 0, 'sentence': 'saving childrens lives is at the heart of our work explains three simple proven lifesavers'}
# {'user_id': 0, 'sentence': 'millions of the worlds poorest are farmers they will be hit hardest by climate change'}
# {'user_id': 0, 'sentence': 'precision maps are powerful new tool in the fight against malaria via and'}
# {'user_id': 0, 'sentence': 'bio hermes study is the first to compare results of blood and digital biomarker tests with imaging and traditional cognitive tests this could help identify alzheimers earlier and detect progression of the disease to help us get closer to cure'}
# {'user_id': 0, 'sentence': 'anyone interested in helping create better world should read this book'}
# {'user_id': 0, 'sentence': 'this is great example of how data is making it easier for researchers to identify novel targets and mechanisms for alzheimers disease we need more data sharing to increase our chances of finding breakthrough'}
# {'user_id': 0, 'sentence': 'the students who joined melinda and me for this minutes segment are incredible role models for other young people we learned lot from talking with them'}
# {'user_id': 0, 'sentence': 'as long as women are invisible the benefits of development cant reach them heres how we can change this'}
# {'user_id': 0, 'sentence': 'tuberculosis is an often forgotten disease that im hoping can get the attention it deserves'}
# {'user_id': 0, 'sentence': 'south africa did the right thing by reporting these cases they have invested heavily in randd including genomic sequencing capabilities which have made it possible to quickly identify variants like omicron and help the world respond appropriately'}
# {'user_id': 0, 'sentence': 'anybody can learn to code and everyone should give it try'}
# {'user_id': 0, 'sentence': 'recently published fascinating volume of essays on the future of farming'}
# {'user_id': 0, 'sentence': 'avoiding climate disaster will require new industrial revolution im excited to see energy catalyst announce the first private sector anchor partners who will work together to build the clean industries of the future'}
# {'user_id': 0, 'sentence': 'if were going to end the acute phase of the pandemic life saving drugs like molnupiravir must be available to everyone who needs them'}
# {'user_id': 0, 'sentence': 'how do we use technology and innovation to solve todays problems thats the question david sengeh sierra leones chief innovation officer and education minister is looking to answer with the countrys national innovation and digital strategy'}
# {'user_id': 0, 'sentence': 'im excited about revolutionary invention thats already helping more kids get vaccinated'}
# {'user_id': 0, 'sentence': 'im so lucky to have melinda as my partner in life and work she inspires me every day'}
# {'user_id': 0, 'sentence': 'by investing in direct air capture clean hydrogen long duration energy storage and sustainable aviation fuel well create new industrial revolution that will power the global clean energy economy'}
# {'user_id': 0, 'sentence': 'the power of phone in every pocket is transforming the lives of the poor'}
# {'user_id': 0, 'sentence': 'our friend is one of the greatest investors of all time this may be his best investment'}
# {'user_id': 0, 'sentence': 'here are three facts from the site that max thinks everyone should know'}
# {'user_id': 0, 'sentence': 'i loved meeting these young people who are so passionate about fighting poverty'}
# {'user_id': 0, 'sentence': 'great economist article on how africans are attacking the barriers to higher productivity'}
# {'user_id': 0, 'sentence': 'in there were new polio cases last year there were just heres what made this progress possible'}
# {'user_id': 0, 'sentence': 'one in every people on earth cant see but amazingly cure for blindness is now in sight'}
# {'user_id': 0, 'sentence': 'congrats on winning your th grand slam cant wait to see your game up close on march at the'}
# {'user_id': 0, 'sentence': 'youre times less likely to be killed today by lightning bolt than you were at the turn of the th century and thats not because there are fewer thunderstorms'}
# {'user_id': 0, 'sentence': 'india has administered billion vaccine doses testament to indias innovation ability to manufacture at scale and the efforts of millions of health workers backed by cowin congratulations'}
# {'user_id': 0, 'sentence': 'i couldnt agree more we need to think big and aim high'}
# {'user_id': 0, 'sentence': 'im big fan of its great to see him support the fight to'}
# {'user_id': 0, 'sentence': 'in there were new polio cases an hour in there were just cases heres how we get to zero'}
# {'user_id': 0, 'sentence': 'if you are interested in clean energy i strongly encourage you read this free book'}
# {'user_id': 0, 'sentence': 'this revolutionary vaccine has had remarkable success in curbing meningitis cases in africa'}
# {'user_id': 0, 'sentence': 'of course the full extent of the pandemics impact on the sdgs will take years to fully understand as more and better data becomes available and this data doesnt diminish the very real suffering the pandemic has caused for people everywherefar from it'}
# {'user_id': 0, 'sentence': 'i really enjoyed reading these five books this year and i think you will too'}
# {'user_id': 0, 'sentence': 'i cant wait for readers to get their hands on my new favorite book you can download free chapter of enlightenment now here'}
# {'user_id': 0, 'sentence': 'mind blowing fact more energy from the sun hits the earth in one hour than humans use in an entire year'}
# {'user_id': 0, 'sentence': 'i hope you find at least one book here that inspires you to go off the beaten path'}
# {'user_id': 0, 'sentence': 'congrats to and on new power looks like an interesting read'}
# {'user_id': 0, 'sentence': 'great caltech commencement address is powerful defense of science via'}
# {'user_id': 0, 'sentence': 'this map from shows the progress weve madebut also highlights how much work we have left to do'}
# {'user_id': 0, 'sentence': 'stories like these remind me of why melinda and i started our foundation'}
# {'user_id': 0, 'sentence': 'i recently caught glimpse at the future of higher ed'}
# {'user_id': 0, 'sentence': 'if you were stranded on desert island what music would you want to have heres my list'}
# {'user_id': 0, 'sentence': 'ahead of i want to highlight two heroes who have helped make stunning progress in the fight against aids'}
# {'user_id': 0, 'sentence': 'jenn and nayel its impossible to put into words how happy it makes me to see you filled with joy on your wedding day im so proud of you both for everything youve accomplished in your lives so far and everything you will do with your future together'}
# {'user_id': 0, 'sentence': 'has been year full of progress im excited to share what was possible reflection on the incredible work the'}
# {'user_id': 0, 'sentence': 'the world has made incredible progress toward ending polio todays news reminds us why we must keep up the fight'}
# {'user_id': 0, 'sentence': 'progress is coming faster than ever hit refresh is thoughtful exploration of the future of technology'}
# {'user_id': 0, 'sentence': 'there has been lot of progress recently so i want to give you an update on my energy work'}
# {'user_id': 0, 'sentence': 'most people know as one of the greatest tennis players of all time but his work off the court is also impressive if youre federer fan i encourage you to read his recent post about his journey from tennis player to philanthropist'}
# {'user_id': 0, 'sentence': 'this imaging technique could make it easier for aid to reach the people who need it the most'}
# {'user_id': 0, 'sentence': 'is week away tweet or rt using and our foundation will donate to end child poverty'}
# {'user_id': 0, 'sentence': 'jimmy and rosalynn carter have been married for years he gave melinda and me some advice'}
# {'user_id': 0, 'sentence': 'women spend more time than men doing unpaid work melinda explains how we can change that'}
# {'user_id': 0, 'sentence': 'you were good sport jimmy pro tip never choose glass in poop water challenge'}
# {'user_id': 0, 'sentence': 'alzheimers research is one of the most exciting frontiers of science im optimistic we can alter the course of the disease if we make progress in five key areas including the development of better diagnostic'}
# {'user_id': 0, 'sentence': 'if i were starting out as college grad and looking for chance to make an impact i would consider these fields'}
# {'user_id': 0, 'sentence': 'the sun is the most plentiful source of renewable energy we have and the race is on to harness its power'}
# {'user_id': 0, 'sentence': 'only half of the american students who start college will graduate thats why im constantly on the lookout for schools that defy the odds'}
# {'user_id': 0, 'sentence': 'people often ask me how they can help save lives heres an easy way'}
# {'user_id': 0, 'sentence': 'this is great investment for every spent on sanitation there is return'}
# {'user_id': 0, 'sentence': 'i recently visited lab doing super cool energy worka good reminder of why governments should sponsor randd'}
# {'user_id': 0, 'sentence': 'tanzania hopes to eliminate one of the worlds most painful diseases by from what i saw in this village im optimistic they will'}
# {'user_id': 1, 'sentence': 'soooo whip shots sold out in less then five minutes deum aint know yall was into liquor like that check back daily for different flavor the entire month of december'}
# {'user_id': 1, 'sentence': 'happy siblings day i cant front kk looks like henny here anyways they brought the hennesssssyyyy'}
# {'user_id': 1, 'sentence': 'lana del rey just said she wants to collab with migos here for it needs to happen immediately tell offset'}
# {'user_id': 1, 'sentence': 'cause ya make lies about me all the time leave me the fuck alone ya be eating my dick with mayonnaise even when im chillin then run with it'}
# {'user_id': 1, 'sentence': 'i need to go to cardi concert thats bucket list thanggg'}
# {'user_id': 1, 'sentence': 'and put the video on the trending page mill less than hrs'}
# {'user_id': 1, 'sentence': 'exactly people trying to find excuses and reasons to okay their bs and thats even more twisted folks will scream protect'}
# {'user_id': 1, 'sentence': 'came out today and its so good i had to improv over it congrats and'}
# {'user_id': 1, 'sentence': 'yes yes yes finally im getting my whip shots wont he do it'}
# {'user_id': 1, 'sentence': 'one thing cardi doesnt do is brag constantly when she should so when she does celebrate and bring up her stats she deserv'}
# {'user_id': 1, 'sentence': 'twitter would be so dry if cardi was offline all day they wouldnt have any entertainment'}
# {'user_id': 1, 'sentence': 'spotify update rumors by and us plays ww plays'}
# {'user_id': 1, 'sentence': 'kingmeech the haters need cardi the funny thing is it only helps her'}
# {'user_id': 1, 'sentence': 'i wonder if gen zs watch maury when they miss school or that was just us'}
# {'user_id': 1, 'sentence': 'naaaaa man be hating but it really be women in these comments and on youtube talkin the most shit putting women down but fake preach unity and women progression'}
# {'user_id': 1, 'sentence': 'so and had an assignment to complete and they completed it alright was craaaaazy'}
# {'user_id': 1, 'sentence': 'sign up for whip shots now to be notified and get all the updates on its release and older'}
# {'user_id': 1, 'sentence': 'you will be surprised how fast we spread in matter of weeks'}
# {'user_id': 1, 'sentence': 'i hate that i only did one close up look with this make up anyways'}
# {'user_id': 1, 'sentence': 'cardi blasts social media for bullying mac miller ya dont care till somebody is gone'}
# {'user_id': 1, 'sentence': 'exactly this was on of and i wasnt complaining about fans defending me i was talking about one person that said im being inconsiderate to bg cause i wasnt going live enough like other rappers but quit when i went on live and got drag for nails'}
# {'user_id': 1, 'sentence': 'babygirl you killed it outfits and choreography and yassss you did that period but to end ever'}
# {'user_id': 1, 'sentence': 'she brought her gangster bitch vibes back the real cardi is back bitch'}
# {'user_id': 1, 'sentence': 'he whole racist and he call me bitch and claim my fans got mommy and daddy issues and you want me to do what again'}
# {'user_id': 1, 'sentence': 'cardi said i got it out the club they didnt do me no favors'}
# {'user_id': 1, 'sentence': 'cardis performance is now trending at on us youtube with nearly views'}
# {'user_id': 1, 'sentence': 'im seeing satan rlly sending his people for this pregnancy chin up girl did what needed to be done'}
# {'user_id': 1, 'sentence': 'facts i left for one day and they was like deum i miss the bitch let me make this lie up so i can have reason to talk about her'}
# {'user_id': 1, 'sentence': 'im so happy to be in generation where i get to see two women of color being represented so strongly in positive way i'}
# {'user_id': 1, 'sentence': 'ommmmmmmmggggggggg naaaa imagine getting food advice from drew barrymore i love meat so much and i love crab legs but i havent been digesting food the same no more specially red meat i want to start something healthier an yet tasty cause i love flavor'}
# {'user_id': 1, 'sentence': 'is the most hated but shes the only always speaking out facts'}
# {'user_id': 1, 'sentence': 'my first time buying song ik yall proud of me i bought it twice and it was accident but oh well i aint know'}
# {'user_id': 1, 'sentence': 'one more thing i want to make clear to americans colonization did not just happened in the usa actually the first diaspora boat and slaves arrive in the dominican republic our haitian and dr brothers and sisters were put against each other by their colonizers spain and france'}
# {'user_id': 1, 'sentence': 'me rapping every other day new hair come take me out this mugler me in my fashion nova'}
# {'user_id': 1, 'sentence': 'cardi said niggas at the woodworks know we never dated stop lyin on the pussy when you know you never ate it'}
# {'user_id': 1, 'sentence': 'i get big paper so i deal wit big haters got it out the mud they aint do me no favors okay cardi'}
# {'user_id': 1, 'sentence': 'are we still pretending cardi doesnt make bops cause big paper is bop'}
# {'user_id': 1, 'sentence': 'its so sad how these people devote so much time and energy that could be used to make their life better just to drag'}
# {'user_id': 1, 'sentence': 'omg type sh really is so good yall really slid cardi knew what time it was'}
# {'user_id': 1, 'sentence': 'me when the republicans and conservatives have temper tantrums cause of wap every month'}
# {'user_id': 1, 'sentence': 'not finessed but the others yes wow how can i forget'}
# {'user_id': 1, 'sentence': 'oooo man i dont think normani fans know who they dealing with bardigang are real fast and determined yall ready'}
# {'user_id': 1, 'sentence': 'wow i got two diamond records thank you sooo much for including me on this song and this is the song i cater to my daughter every time i perform it im forever grateful'}
# {'user_id': 1, 'sentence': 'the quotes really show me that people are not as bright sis'}
# {'user_id': 1, 'sentence': 'i million likes oh cardi need to hurry up and put this in bottle'}
# {'user_id': 1, 'sentence': 'omgggg i must say down south men are way more generous wit gifts and spending ny nikkas be fake stingy with the pockets unless their ugly'}
# {'user_id': 1, 'sentence': 'wttttffff i need your info imma send you all the colors'}
# {'user_id': 1, 'sentence': 'you two did that remember the haters are only talking about and hating because your verse i'}
# {'user_id': 1, 'sentence': 'right they literally like the nicest and sweetest people ive seen im glad to be apart'}
# {'user_id': 1, 'sentence': 'wait wait wait when have i ever worked for them or they ever worked for me they manage plenty of your favorite artist but never cardi they dont work for my label and only person who ever manage me was shaft and for months'}
# {'user_id': 1, 'sentence': 'if i ever go broke is not because of jewelry cars or purses its because of roblox like i need discount or gift card for that game cause my kid be running it up'}
# {'user_id': 1, 'sentence': 'its one thing to not like an artist for their music but to come on here and make up bunch of weird narratives based on ho'}
# {'user_id': 1, 'sentence': 'not gone lie cardi did what she needed to do on big paper she popped her shit'}
# {'user_id': 1, 'sentence': 'these makeup videos are so lit she ate that credits lexdelani on'}
# {'user_id': 1, 'sentence': 'heyyy i got tattoo in honor of the lyrics of be careful and tomorrow is my birthday i love uuu'}
# {'user_id': 1, 'sentence': 'really said its my dick and i want it now somebody call jg wentworth'}
# {'user_id': 1, 'sentence': 'sweet baby boymy grandma passed due to diabetes as well i hope god give you strength mind soon when you feel the most alone you will feel your mom presence and when you least expect it she will visit your dreams sending you strong virtual hugs i wish i can give you real one'}
# {'user_id': 1, 'sentence': 'i mean i landed so i had to wake up right'}
# {'user_id': 1, 'sentence': 'give me fish and imma eat teach me how to fish and we gone eat'}
# {'user_id': 1, 'sentence': 'had to pick up little something for the wife as well cardi reebok'}
# {'user_id': 1, 'sentence': 'off topic but im annoyed that i woke up maaa early even tho i went to sleep late and every is sleeping and i want to start recording'}
# {'user_id': 1, 'sentence': 'imagine how tired we are of these fake accusations every business days cardi is really in these btches minds rent free'}
# {'user_id': 1, 'sentence': 'and its only available to view in the us thanks america'}
# {'user_id': 1, 'sentence': 'i heard that cardi up song at public event over the weekend and yea man she got one lo'}
# {'user_id': 1, 'sentence': 'this was stunning the choreo maam the song is also sexy banger catchy perfect use of the sampl'}
# {'user_id': 1, 'sentence': 'omfg normani and cardi bs video for wild side is firreeeeee'}
# {'user_id': 1, 'sentence': 'wild side by normani ft cardi is the trending video on youtube'}
# {'user_id': 1, 'sentence': 'the number of times i hit replay on this video tho i still cant get over it normani normani you and'}
# {'user_id': 1, 'sentence': 'its literally filter ya will see sparkles on it and still act clueless and dumb'}
# {'user_id': 1, 'sentence': 'cardi looked so good in the rumors video and she been going hard on these features'}
# {'user_id': 1, 'sentence': 'yes why not princess parties unlimited toys vacations and pools my kid loves the pool and i went to the pool like times in my childhood different flavor cereal not just raisin bran'}
# {'user_id': 1, 'sentence': 'soo lem me see how to get these purple joints from the cardi collection'}
# {'user_id': 1, 'sentence': 'fifteen thousand dollars billion views later wow thats crazy super dope thank you all for all the support through out the years back to the lab love and appreciate yall'}
# {'user_id': 1, 'sentence': 'lmao cardi follows over thousand people on ig how dont like her but you spending your free time going through every'}
# {'user_id': 1, 'sentence': 'my first colorway of the classic leather cardi brand new silhouette launches globally am est'}
# {'user_id': 1, 'sentence': 'meu corpo espirito sentirem se musica incrivel voce pode nao entender as palavras ritmo domina sua alma eu amo'}
# {'user_id': 1, 'sentence': 'im really busy but in the meantime check out bruise soundtrack on all platforms love you guys'}
# {'user_id': 1, 'sentence': 'i got another secret muahahahaha in the mean time take me for ride boy'}
# {'user_id': 1, 'sentence': 'me listening to this new cardi khaled track sis went off'}
# {'user_id': 1, 'sentence': 'i hope my girls lizzo and normani are performing at the vmas please please please'}
# {'user_id': 1, 'sentence': 'its the year for and song wap its the first female rap collab to debu'}
# {'user_id': 1, 'sentence': 'i like selena tho i defend her cause she is such sweetheart in celebs get picked apart all the time but she is just to sweet to go thru that if she wants to leave leave cause you want too not cause of these fuckers'}
# {'user_id': 1, 'sentence': 'this was sylvester before he died dowen killed this bright young man the pain he suffered dowen must pay'}
# {'user_id': 1, 'sentence': 'young ma gt gt gt gt gt why she went so hard on no mercy'}
# {'user_id': 1, 'sentence': 'dont confuse and compare my sexual confidence with anything that has to do with religion ya keep putting me in these tweets and i dont play that shit i have very strong faith in god and i dont play with him neither leave me then fuck alone'}
# {'user_id': 1, 'sentence': 'megan thee stallion performing wap at sports illustrated swimsuits launch event'}
# {'user_id': 1, 'sentence': 'when you stand up for yourself they claim your problematic and sensitive when you dont they tear you apart until you crying like this whether you skinny big plastic they going to always try to put their insecurities on you remember these are nerds looking at the popular table'}
# {'user_id': 1, 'sentence': 'get new york city night vibes with shining new metallics classic leather cardi out now ht'}
# {'user_id': 1, 'sentence': 'its ok babe remember cardi this cardi that makes more paper'}
# {'user_id': 1, 'sentence': 'this is my mother cardi she is walking obsession'}
# {'user_id': 1, 'sentence': 'oommgggg they look so bute on her omg my heart cant take it'}
# {'user_id': 1, 'sentence': 'good morning everyone its sunday dont get distracted by devils and trolls focus on your goals'}
# {'user_id': 1, 'sentence': 'visual of leaving the studio after she recorded her type shit verse for'}
# {'user_id': 1, 'sentence': 'they ask you something and when you answer they claim youre mad or bothered'}
# {'user_id': 1, 'sentence': 'the one in the middle is me im not puerto rican'}
# {'user_id': 1, 'sentence': 'cardi is the only celebrity that have the power to get all the stans mad just by defending herself lmao we love you so much'}
# {'user_id': 1, 'sentence': 'wild side coreografia normani feat cardi amanha as tomorrow pm canal ramana borba'}
# {'user_id': 1, 'sentence': 'i wan na re do this song in spanish i love this song'}
# {'user_id': 1, 'sentence': 'mood and i dont wan na make you unhappy if you not happy then you free to go on'}
# {'user_id': 1, 'sentence': 'no ya was callin me dumb terrorist all types of bitches cancel cardi and you expect me to apologize over fuckin painting thats from century way earlier from the genocidedont bringblminto this'}
# {'user_id': 2, 'sentence': 'research suggests that of people experienced discrimination in the past year and of people'}
# {'user_id': 2, 'sentence': 'nice got ta love that oh so environmentaly responsible ns mining industry not your grandfathers dont ya know step'}
# {'user_id': 2, 'sentence': 'when the work of caught the eye of actor and filmmaker she had no idea it would lead'}
# {'user_id': 2, 'sentence': 'media relations now tell me mandatory environmental effects monitoring reports for may con'}
# {'user_id': 2, 'sentence': 'with coming up we created the trevor projects coming out handbook for lgbtq young people'}
# {'user_id': 2, 'sentence': 'conservative leader andrew scheer said gay couples lack inherent quality of marriage in video taped spee'}
# {'user_id': 2, 'sentence': 'hideous flooding kills scores in iran and even the petro states energy minister attributes the crisis to climate change'}
# {'user_id': 2, 'sentence': 'all the chiefs of mikmaqi have made it clear that they are against the mills audacious pipe in the strait plan'}
# {'user_id': 2, 'sentence': 'the state of affairs here in the land of gratitude to for using her powerful voice to lift those'}
# {'user_id': 2, 'sentence': 'happy lesbian history is cherished part of our history we honor the courageous women'}
# {'user_id': 2, 'sentence': 'this is illegal this is illegal this is illegal this is illegal this is illegal this is illegal this is illegal this is'}
# {'user_id': 2, 'sentence': 'hideous fires the worst in the regions history are devastating america there were dead wild animals everywhere'}
# {'user_id': 2, 'sentence': 'the documentary that tiff calls urgent was inspired by dr ingrid waldrons book by the same na'}
# {'user_id': 2, 'sentence': 'thank you for following the and not the money now its time for you to act'}
# {'user_id': 2, 'sentence': 'the tales of the city somehow heartwarming and heart wrenching highly recommend is talented loooove'}
# {'user_id': 2, 'sentence': 'this is what my community has to deal with everyday thanks for northern pulp and they want to build pipe into the oc'}
# {'user_id': 2, 'sentence': 'heres my review of and ian daniels theres something in the water which has one more screening at'}
# {'user_id': 2, 'sentence': 'my days of mercy with and is amazing its complex and real must see without doubt'}
# {'user_id': 2, 'sentence': 'me i dont think billionaires should concentrate wealth while employing people who are sleeping in cars working zillion hours'}
# {'user_id': 2, 'sentence': 'refugees dont flee their homes based on tweet they leave their loved ones their homeland and their worldly possessi'}
# {'user_id': 2, 'sentence': 'one of the things that struck me in the article about today was how life affirming and saving access to'}
# {'user_id': 2, 'sentence': 'flashback tiny detectives with for im lucky to call this wonderful human friend even luckier to have made film with her because shes talented af you can see my days of mercy now on'}
# {'user_id': 2, 'sentence': 'have you already made your calls emails let us know tag us keep tweeting and posting to demand'}
# {'user_id': 2, 'sentence': 'soooo much love last night at world premiere of our film theres something in the water'}
# {'user_id': 2, 'sentence': 'thank you for releasing the first clip from the doc i directed with based on book theres something in the water humbled to have met all the incredible people in this film it premieres this sunday at pm'}
# {'user_id': 2, 'sentence': 'humbled to have met dorene bernard and other grassroots grandmothers who are protecting the water and land from alton gas an'}
# {'user_id': 2, 'sentence': 'human rights lawyer who has helped bring charges in european court against bush era torturers says figu'}
# {'user_id': 2, 'sentence': 'the truth is everything in life has its breaking point my fear is that the planets equilibrium has been lost we are'}
# {'user_id': 2, 'sentence': 'ice arrested hundreds of people in raids now devastated children are without their parents'}
# {'user_id': 2, 'sentence': 'exxon wouldnt let this indigenous leader speak so lets spread the word ourselves'}
# {'user_id': 2, 'sentence': 'the time for is now it is possible all we need is for leaders act'}
# {'user_id': 2, 'sentence': 'as we celebrate th anniversary here are few other important moments in rights over the years'}
# {'user_id': 2, 'sentence': 'greta thunberg they see us as threat because were having an impact'}
# {'user_id': 2, 'sentence': 'not drill new poll shows that we are beating by two points yall know we cant stop now but'}
# {'user_id': 2, 'sentence': 'with all due respect when are you guys going to stop sitting on the fence on this thing still evaluating'}
# {'user_id': 2, 'sentence': 'theres hope and light in seeing so many beautiful trans people standing up in the face of oppression'}
# {'user_id': 2, 'sentence': 'rebecca moore and other water protectors have message clearly stating that margaret miller the nova scotia govt and alton gas have not adequately consulted the indigenous community'}
# {'user_id': 2, 'sentence': 'the crew has been willfully destroying our traplines and today denied an matriarch from ente'}
# {'user_id': 2, 'sentence': 'the entire gulf needs immediate protection the gulf of st lawrence is losing oxygen faster than'}
# {'user_id': 2, 'sentence': 'an interview i gave to now atlantic the unequal impact of climate change the western star'}
# {'user_id': 2, 'sentence': 'nova scotians want government with the guts to say no to pulp mill stick to your guns premier you'}
# {'user_id': 2, 'sentence': 'in our new issue lez royalty opens up about standing in her truth shooting sex scenes and her fantastic'}
# {'user_id': 2, 'sentence': 'alert amy coney barrett trumps anti civil rights supreme court nominee was just voted out of senate committee th'}
# {'user_id': 2, 'sentence': 'so can you please explain why there is no commitment from the federal level regarding northern pulps hope'}
# {'user_id': 2, 'sentence': 'the middle ground is exactly what biden and obamas policy was during their time in the white house frack everything in'}
# {'user_id': 2, 'sentence': 'homeward bound to this pic says it all thanks to everyone in to who watched the film and to those who'}
# {'user_id': 2, 'sentence': 'this is one of my proudest moments please watch on its the tv series we all deserve'}
# {'user_id': 2, 'sentence': 'the mill has lost its social license through over half century of abuse and the public has had enough they sa'}
# {'user_id': 2, 'sentence': 'i know john perkins he is pacifist buddhist there is no way the rcmp had grounds to arrest him does'}
# {'user_id': 2, 'sentence': 'and documentary theres something in the water is must see for all canadians'}
# {'user_id': 2, 'sentence': 'dale andrew poulette and rachael greenland smith the fight to save the shubenacadie river'}
# {'user_id': 2, 'sentence': 'by overriding the veto on arkansas has put itself in the lead of race to the bottom fueled by fear and disinfor'}
# {'user_id': 2, 'sentence': 'once again authorities in are violently targeting lgbti people while there is no justice people wil'}
# {'user_id': 2, 'sentence': 'yesterday coastal gaslink contractors illegally bulldozed through one of our traplines damage to the trapline is dire'}
# {'user_id': 2, 'sentence': 'tonight at we got to experience transcending production based on serious topic shot in nova scotia amaz'}
# {'user_id': 2, 'sentence': 'will finally recognize their complicity in from the incredible women in this film'}
# {'user_id': 2, 'sentence': 'our next guest is who is featured in the documentary theres something in the water directed by'}
# {'user_id': 2, 'sentence': 'with the world and the global climate justice movement both the only responses that matter are truly transforma'}
# {'user_id': 2, 'sentence': 'industry and govt have refused to do proper archaeological survey of the proposed coastal gaslink man camp site so'}
# {'user_id': 2, 'sentence': 'jchisholm theres something in the water was moving it affected every inch of my being thank you'}
# {'user_id': 2, 'sentence': 'so today michael enright privileged white guy with canadas public broadcaster gets to abuse his privileged'}
# {'user_id': 2, 'sentence': 'canadians imagine we live in green country because if you look at it from the air its pretty green the reality is when'}
# {'user_id': 2, 'sentence': 'my website is going on with me will yours heres everything you need to join'}
# {'user_id': 2, 'sentence': 'feeling so privileged this morning to hear the amazing alanis obomsawin speak so passionately from the heart about th'}
# {'user_id': 2, 'sentence': 'normally at this point in season of americas corn crop is in the ground but thanks to endless rain its this'}
# {'user_id': 2, 'sentence': 'climate emergency has been declared in wales following protests demanding politicians take action on climate change'}
# {'user_id': 2, 'sentence': 'i finished in one weekend we need more beautiful queer stories told thanks'}
# {'user_id': 2, 'sentence': 'thousands of immigrants forced into solitary confinement by ice not for breaking any rules but for being physically disabled'}
# {'user_id': 2, 'sentence': 'today some ignorant jacka decides to make racist comment to plfn community member proudly wearing their asek'}
# {'user_id': 2, 'sentence': 'here at the theres something in the water red carpet we get first look at tonights special guests director ellen'}
# {'user_id': 2, 'sentence': 'happy as we mark years since start right by taking action at'}
# {'user_id': 2, 'sentence': 'saw theres something in the water ft documentary about environmental racism in nova scotia'}
# {'user_id': 2, 'sentence': 'code red australia is so hot bats are falling from the trees'}
# {'user_id': 2, 'sentence': 'this outrage happening in bc the first jurisdiction in north america to introduce legislation to implement the un decla'}
# {'user_id': 2, 'sentence': 'step declare climate emergency step next day announce plans for massive new tarsands pipeline step wonder why peopl'}
# {'user_id': 2, 'sentence': 'white males just decided what alabama women can and cant do with their own bodies and lives males cause'}
# {'user_id': 2, 'sentence': 'new interview about theres something in the water screening at tiff ellen page documentary on environmental racism in'}
# {'user_id': 2, 'sentence': 'breaking pacific island leaders declare this declaration makes clear that the current scale of the climat'}
# {'user_id': 2, 'sentence': 'day of press for theres something in the water lucky to have these incredible people in my life it premieres in an hour thank you waldroningrid'}
# {'user_id': 2, 'sentence': 'thanks to and all of the courageous women who are fighting for access to clean water and natural environments'}
# {'user_id': 2, 'sentence': 'you know our movement has the right theory of change when the head of the worlds largest oil cartel calls it the greatest threat'}
# {'user_id': 2, 'sentence': 'nearly migrants found at texas facility with person capacity dhs watchdog'}
# {'user_id': 2, 'sentence': 'single most important stat on the planet co rose parts per million last year nd highest annual rise on record th'}
# {'user_id': 2, 'sentence': 'i will be discussing the documentary theres something in the water and my tiff experience on cbc information morning hal'}
# {'user_id': 2, 'sentence': 'green party leader elizabeth may has unveiled multi pronged plan to help workers in the gas and oil sector transition to'}
# {'user_id': 2, 'sentence': 'proud to be part of this great call when we think about we tend to focus on the built environment but'}
# {'user_id': 2, 'sentence': 'tell gov kristi noem that hb has no place in south dakota and will only harm women and girls in the state who just wan'}
# {'user_id': 2, 'sentence': 'today texas lawmakers will discuss hb another anti trans sports bill the attacks on texas youth have been relentless'}
# {'user_id': 2, 'sentence': 'author of the mill years of pulp and protest talks to about her new film'}
# {'user_id': 2, 'sentence': 'everyone should read book theres something in the water environmental racism in indigenous and black communities'}
# {'user_id': 2, 'sentence': 'happy this is whats needed to stay below degc of warming note that this doesnt include the aspect of eq'}
# {'user_id': 2, 'sentence': 'we will be streaming the show live on twitter or you can tune in right'}
# {'user_id': 2, 'sentence': 'please stop supporting corporations that are destroying our environment it is unfathomable that you arent doing everything possible to change and help with this horrible crisis'}
# {'user_id': 2, 'sentence': 'today south dakota senate committee will be hearing anti trans sb protect trans youth stop this bill'}
# {'user_id': 2, 'sentence': 'hey twitter pals if you can go see in my days of mercy this weekend its fantastic'}
# {'user_id': 2, 'sentence': 'where have been for the last years what about the beneath this fraud of an alleg'}
# {'user_id': 2, 'sentence': 'thank you for caring and for placing the issue on the public record in canadas house of commons lots of fishers si'}
# {'user_id': 2, 'sentence': 'well said ellen page mike pence is an insane zealot who has set lgbtq rights back years and it'}
# {'user_id': 2, 'sentence': 'pumped to see the documentary theres something in the water tonight in based on book'}
# {'user_id': 2, 'sentence': 'join us on journey to see why masks do such good job of stopping the spread of coronavirus'}
# {'user_id': 3, 'sentence': 'great shot btw starship super heavy will not have an entry burn delta is shifted more to the ship so booster entry and heating is lower'}
# {'user_id': 3, 'sentence': 'tesla solar roof powerwall in major new housing development in austin'}
# {'user_id': 3, 'sentence': 'that said the ship landing burn has clear solution my greatest concern is achieving good payload to orbit with rapid and full reusability without which we shall forever be confined to earth'}
# {'user_id': 3, 'sentence': 'haha true i talked to my friends about electric cars constantly in college'}
# {'user_id': 3, 'sentence': 'green flame in this context means engine is burning internal components made of copper this is usually followed by rud rapid unscheduled disassembly'}
# {'user_id': 3, 'sentence': 'falcon and dragon in the hangar at launch complex ahead of launching'}
# {'user_id': 3, 'sentence': 'the hard work by faa us fish and wildlife and texas parks and wildlife is much appreciated as well as the strong local support from cameron county and brownsville south padre'}
# {'user_id': 3, 'sentence': 'tesla sure would appreciate changing the law so that this is not required'}
# {'user_id': 3, 'sentence': 'its not really possible to match the human brain in for any amount of money imo but it will be possible probably in few years'}
# {'user_id': 3, 'sentence': 'it wont need to reach visa speed as regulated exchanges will act as de facto second layer but the perfect should not be the enemy of the good it is still good to increase base layer transaction speed and lower base layer transaction cost'}
# {'user_id': 3, 'sentence': 'btw theres slight error with forward flap design moving section is needed for control but passive section is counter productive as it pushes nose backwards new design rotates fwd flaps more to leeward and further forward to improve moment arm maybe deg apart'}
# {'user_id': 3, 'sentence': 'due to lack of banging civilization might ended with whimper adult diaper sales growth is much higher than baby diaper sales growth'}
# {'user_id': 3, 'sentence': 'hypothetically if they did make lots of electric cars then they would be the leader'}
# {'user_id': 3, 'sentence': 'starship will be crushingly cost effective for earth orbit or moon missions as soon as its operational and rapid reuse is happening mars is lot harder because earth and mars only align every months so ship reuse is limited to dozen times over to year life of ship'}
# {'user_id': 3, 'sentence': 'long way to go to perfect it but starship is really next leve'}
# {'user_id': 3, 'sentence': 'if you dont say anything and engage autopilot it will soon guess based on time of day taking you home or to work or to whats on your calendar'}
# {'user_id': 3, 'sentence': 'sanskrit is ancient and amazing but archaic sumerian is generally agreed to be oldest written language as for what was first spoken its hard to say as no one wrote it down so much history has been lost due to lack of writing on something durable'}
# {'user_id': 3, 'sentence': 'did you buy powerwall utility permission is required for flowing electricity back to grid but usually not if stored in our battery this also enables electricity security for your home utility permission is still needed for when powerwall is full and can stabilize grid'}
# {'user_id': 3, 'sentence': 'dont want to be unreasonable but maybe they should be required to deliver at least one vehicle per billion dollars of valuation before the ipo'}
# {'user_id': 3, 'sentence': 'this might be part of the problem gm is warning owners not to charge their bolts in or near their homes overnight'}
# {'user_id': 3, 'sentence': 'glad its working the sheer amount of work done by spacex engineering production and launch teams is amazing ping should improve dramatically in coming months were aiming for lt ms basically you should be able to play competitive fps games through starlink'}
# {'user_id': 3, 'sentence': 'due to lower gravity you can travel from surface of mars to surface of earth fairly easily with single stage rocket earth to mars is vastly harder'}
# {'user_id': 3, 'sentence': 'by volume production i mean to engines per day thats super high volume for big rocket engines but low volume by automotive standards'}
# {'user_id': 3, 'sentence': 'lot of improvement still coming just from software updates to satellites and terminals'}
# {'user_id': 3, 'sentence': 'fremont shut down for two days parts shortages and restarted yesterday'}
# {'user_id': 3, 'sentence': 'for those wondering i will pay over billion in taxes this year'}
# {'user_id': 3, 'sentence': 'the thing we call money is just an information system for labor allocation what actually matters is making goods and providing services we should look at currencies from an information theory standpoint whichever has least error and latency will win'}
# {'user_id': 3, 'sentence': 'tanstaafl would be better to have small fees than no fees as latter makes robinhood beholden to big trading houses got to pay the bills somehow even etsy has fees'}
# {'user_id': 3, 'sentence': 'an advantage i did have is that my father is talented electrical and mechanical engineer so i was taught lot engineering without appreciating it at the time'}
# {'user_id': 3, 'sentence': 'it has indeed become hard to find which platform has which show'}
# {'user_id': 3, 'sentence': 'physics should be taught with the majesty and beauty it deserves'}
# {'user_id': 3, 'sentence': 'it takes years time from conception to adult to reverse demographic trends'}
# {'user_id': 3, 'sentence': 'i do think that great design and engineering of products are critical but manufacturing and supply chain require orders of magnitude more wor'}
# {'user_id': 3, 'sentence': 'always loved those empire state photos with people eating lunch out on the beam'}
# {'user_id': 3, 'sentence': 'we do need to have the fallout themed party aiming to do that once international travel restrictions are lifted'}
# {'user_id': 3, 'sentence': 'one of them may be in limited operation by end of year'}
# {'user_id': 3, 'sentence': 'i find it more helpful to read follow individual journalists rather than publications any given publication is going to have wide range of views albeit vast majority of stories about any subject are negative perhaps reflecting innate human biases citizen journalism ftw'}
# ...
# {'user_id': 6, 'sentence': 'marriage equality obamacare global climate agreement push for more progress'}
# {'user_id': 6, 'sentence': 'for the third time as president i get to say give it up for the stanley cup champs my hometown chicago blackhawks'}
# {'user_id': 6, 'sentence': 'america now has the lowest uninsured rate on record thanks to repealing it doesnt make sense'}
# {'user_id': 6, 'sentence': 'join the truth team and spread the facts on issues that matter'}
# {'user_id': 6, 'sentence': 'get some face time with president obama enter now for your chance to meet him'}
# {'user_id': 6, 'sentence': 'every nominee including kennedy in an election yeargot an up or down vote on serving as senate judiciary chairman or'}
# {'user_id': 6, 'sentence': 'live president obama and are participating in the annual white house'}
# {'user_id': 6, 'sentence': 'watch on why todays decision sets us back even further on immigration reform'}
# {'user_id': 6, 'sentence': 'say that senate leaders should stop hiding behind excuses and give judge garland fair hearing'}
# {'user_id': 6, 'sentence': 'more than million new jobs the strongest two years of job growth since the an unemployment rate cut in half president obama'}
# {'user_id': 6, 'sentence': 'times running out to before the january deadline check out your options'}
# {'user_id': 6, 'sentence': 'climate change is not too big of challenge to solve were making good headway'}
# {'user_id': 6, 'sentence': 'seven years ago we made the single biggest investment in clean energy in our history president obama'}
# {'user_id': 6, 'sentence': 'in the weekly address retired federal judge timothy lewis joins biden to discuss the vacancy'}
# {'user_id': 6, 'sentence': 'there is no excuse to delay the nominationadd your name to petition if you agree'}
# {'user_id': 6, 'sentence': 'the obstruction of our supreme court is completely unprecedented sign the petition telling the senate'}
# {'user_id': 6, 'sentence': 'we cant rest weve got to keep pushing for equality and acceptance and tolerance president obama'}
# {'user_id': 6, 'sentence': 'president obama has taken unprecedented steps to protect our land and water for future generations'}
# {'user_id': 6, 'sentence': 'senate leaders have recognized judge garlands impeccable credentials in the past he deserves fair hearing and an up or down vote'}
# {'user_id': 6, 'sentence': 'huge day for our great green spinning chunk of awesome thank you world leaders for taking'}
# {'user_id': 6, 'sentence': 'its time for senate leaders to put politics aside and fill the supreme court vacancy'}
# {'user_id': 6, 'sentence': 'add your voice to the push for fair supreme court nomination process'}
# {'user_id': 6, 'sentence': 'because of the insurance is better for everyone no matter where its purchased'}
# {'user_id': 6, 'sentence': 'today is historic day in the fight to protect our planet for future generations president obama'}
# {'user_id': 6, 'sentence': 'sign the petitionjoin the thousands of voices speaking up for fair supreme court nomination process'}
# {'user_id': 6, 'sentence': 'we all have to do our job including the senate'}
# {'user_id': 7, 'sentence': 'magazine do know just how little gives damn about the rights opinion'}
# {'user_id': 7, 'sentence': 'president trump just did something he bashed obama for doing years ago'}
# {'user_id': 7, 'sentence': 'says the star who taught me how to use youtube next time i see you ill hug you to death'}
# {'user_id': 7, 'sentence': 'almost time to hit the road the series premieres tuesday august exclusively on ht'}
# {'user_id': 7, 'sentence': 'all her guy best friends when they hear you and bae broke up ig lifeofxodus'}
# {'user_id': 7, 'sentence': 'did you check out filter on let me see your snaps'}
# {'user_id': 7, 'sentence': 'ill check him out and sorry for the crazy timeline i love engaging but twitter likes fighting'}
# {'user_id': 7, 'sentence': 'todays most meaningful statement came from thank you iyad you briefed very well'}
# {'user_id': 7, 'sentence': 'san antonio tonight at the tobin was magic thank you for special night of warmth and funny'}
# {'user_id': 7, 'sentence': 'wow thank you chelsea this means the world to me and thank you to everyone who went out and got the book'}
# {'user_id': 7, 'sentence': 'how we handled the asymmetry between major party candidates in years from now journalists will look back on that'}
# {'user_id': 7, 'sentence': 'maybe he was in your category and hes still pissed that he lost'}
# {'user_id': 7, 'sentence': 'nc gop researched how black people voted then targeted the law to discourage black people from voting'}
# {'user_id': 7, 'sentence': 'simone biles won nationals broken toes in both feet worlds kidney stone and has carried the burden of being'}
# {'user_id': 7, 'sentence': 'you posted that vaccine card now all them vaccinated people you dont really wan na hang with are hitting you up to go out'}
# {'user_id': 7, 'sentence': 'once we elect the next president the internet should be turned off for six months'}
# {'user_id': 7, 'sentence': 'thank you so much for joining me at my book launch in london tonight such warm and fun audience i wish we could have stayed longer'}
# {'user_id': 7, 'sentence': 'i fucked up on the podcast with douglas murray and said that people got arrested lighting fires in portland that turns out'}
# {'user_id': 7, 'sentence': 'washington dc this weekend you showed me love on another level thank you for sold out shows at the kennedy center what dream'}
# {'user_id': 7, 'sentence': 'is there tape of trump saying the word if it surfaces will there even be consequences breaks it down'}
# {'user_id': 7, 'sentence': 'dude i told you the tea was hot wtf why are you trying to hurt me'}
# {'user_id': 7, 'sentence': 'trevor noah blew my mind yall go see him live thank you for bringing your perspective and humor to loy'}
# {'user_id': 7, 'sentence': 'i just watched the movie sorry to bother you its one of the most engaging challenging entertaining scary funny insane movies ive ever watched please go watch it you wont be disappointed'}
# {'user_id': 7, 'sentence': 'throwing it back you can watch the full video here gt enjoy'}
# {'user_id': 7, 'sentence': 'donald trump in this is my boardroom its not locker room maria youre fired tsu'}
# {'user_id': 7, 'sentence': 'confirmed that facebook lets me exclude black asian and hispanic people from seeing my ads why cant i exclude white people'}
# {'user_id': 7, 'sentence': 'nd show added pre sale starts now with promo code fnycf'}
# {'user_id': 7, 'sentence': 'what fantastic start to the weekend seattle your energy blew the roof off the arena tonight thank you'}
# {'user_id': 7, 'sentence': 'nyc dont miss seeing my buddy new one man show unacceptable starting aug th'}
# {'user_id': 7, 'sentence': 'trust me i feel you but surely he understands his platform extends beyond just himself he can affect so many future voters'}
# {'user_id': 7, 'sentence': 'one chapter in and im hooked on moving insightful funny but we got ta talk about the real deal'}
# {'user_id': 7, 'sentence': 'why couple earning year can still find it hard to get by'}
# {'user_id': 7, 'sentence': 'i know assault rifles i carried one in iraq they have no place on americas streets'}
# {'user_id': 7, 'sentence': 'phoenix and tuscon thank you for bringing that arizona heat to the shows this weekend i had great time with yall'}
# {'user_id': 7, 'sentence': 'so you cant be american and hispanic also funny to see anti immigrant arguments from canadian immigrant'}
# {'user_id': 7, 'sentence': 'true fact i was reluctant to write todays col because i knew journos would hate it but it felt like moral duty'}
# {'user_id': 7, 'sentence': 'the only person having worse day than james comey is lil bow wow'}
# {'user_id': 7, 'sentence': 'if youre going to the edinburgh festival this year dont miss michelle wolf shes as funny as funny gets'}
# {'user_id': 7, 'sentence': 'all i want for black entertainers is for them to be able to grow old'}
# {'user_id': 7, 'sentence': 'i really think we dont spend enough time looking at how bad click bait headlines are for our society they cause panic confusion anger and misinformation the articles have nuance the headlines do not omicron killing everyone all hospitals overwhelmed'}
# {'user_id': 7, 'sentence': 'the great political crisis we face is not voter fraud which barely exists its voter suppression and the denial of voting'}
# {'user_id': 7, 'sentence': 'im excited to announce my brand new back to abnormal world tour with special ticket presale going down tomorrow at am signup at and use the code herewego to get tickets before anyone else were coming back baby'}
# {'user_id': 7, 'sentence': 'after spanish company started day workweek absenteeism fell revenue grew at same rate as before of em'}
# {'user_id': 7, 'sentence': 'to republicans who remain quiet or tacitly support trumps immigration ban history will remember you as cowards'}
# {'user_id': 7, 'sentence': 'brb freaking out we went on to talk and registering to vote watch us at pmet tonight'}
# {'user_id': 7, 'sentence': 'the wrong president can harm so many more people than one person can help its not one or the other vote is also protest'}
# {'user_id': 7, 'sentence': 'food stamp fraud costs the us less than the cost to taxpayers for just months of trumps family living in nyc but yeah sta'}
# {'user_id': 7, 'sentence': 'its because he was teaching me how to play valorant my bad'}
# {'user_id': 7, 'sentence': 'new ben carson says he is resigning from the trump administration over the capitol riots apparently unaware his term en'}
# {'user_id': 7, 'sentence': 'did trump just shove another nato leader to be in the front of the group'}
# {'user_id': 7, 'sentence': 'im so grateful to every person who took the time to listen to my audio book year later and were still on the bestseller list thank you'}
# {'user_id': 7, 'sentence': 'if youre ever watching movie with your parents and sex scene comes on give it second then look at your parents an'}
# {'user_id': 7, 'sentence': 'you know how confident you got ta be in your karate skills to fight in another dimension ya mama took you to karate class ne'}
# {'user_id': 7, 'sentence': 'hanging out backstage pre show in milwaukee its gon na be fun night'}
# {'user_id': 7, 'sentence': 'love hearing interview today from talking inclusion and optimism'}
# {'user_id': 7, 'sentence': 'wrapping up our tour with and few new friends tonight htt'}
# {'user_id': 7, 'sentence': 'thank you to everyone that came out to the budweiser events center arena last night in loveland co cant wait to come back ig stlouistolouisville'}
# {'user_id': 7, 'sentence': 'im glad youre wearing the official uniform see you all tonight'}
# {'user_id': 7, 'sentence': 'sad legacy of roger ailes im sure lot of americans can relate to this online comment'}
# {'user_id': 7, 'sentence': 'columbus ohio was beautiful tonight thank you everyone who came out both shows were amazing'}
# {'user_id': 7, 'sentence': 'scary marijuana stats deaths are annually attributed to excessive use every day people in the us'}
# {'user_id': 7, 'sentence': 'christian horner has michael massees ear i want to speak to the manager'}
# {'user_id': 7, 'sentence': 'is this what you want trump snarled grabbing child and gently injecting free vaccine in her arm huh'}
# {'user_id': 7, 'sentence': 'the ipads will take effect after the next election but thank you for the praise'}
# {'user_id': 7, 'sentence': 'eish if you can help me spell it youll make my day'}
# {'user_id': 7, 'sentence': 'excited to chat with my friend tonight but why does he have to use the pic that looks like im about to introduce bootleg iphone tonight'}
# {'user_id': 7, 'sentence': 'dude cmon i worked all my life on my african accent'}
# {'user_id': 7, 'sentence': 'tweetingvoting posting videovoting your essay on fbvoting if you can vote and you dont youve done nothing'}
# {'user_id': 7, 'sentence': 'if they close the hole how would ted cruz sneak back into cancun'}
# {'user_id': 7, 'sentence': 'remember tonight to set your clock back minutes and if youre trump supporter set your calendar back years'}
# {'user_id': 7, 'sentence': 'trump is calling for extreme vetting of immigrants can his own supporters pass the test'}
# {'user_id': 7, 'sentence': 'yes but zulu tswana and tsonga i learned from the streets'}
# {'user_id': 7, 'sentence': 'people of durham north carolina thank you for two amazing shows last night and thank you for sharing your public bathrooms'}
# {'user_id': 7, 'sentence': 'this time trevor is the one asking the big questions catch my with and'}
# {'user_id': 7, 'sentence': 'charlotte nc youre moving bit faster than i remember but i like it lets add nd show feb th'}
# {'user_id': 7, 'sentence': 'no apology necessary i would have reacted exactly the same way what matters is where we end up merc'}
# {'user_id': 7, 'sentence': 'macron walks directly towards trump swerves at the last second to greet angela merkel first instead spectacular'}
# {'user_id': 7, 'sentence': 'tickets on sale now for my fall tour go to for cities tickets and info'}
# {'user_id': 7, 'sentence': 'its called diving and its very crucial part of the game flopping in basketball is unnecessary'}
# {'user_id': 7, 'sentence': 'saudi arabia gave women permission to drive and this is the first thing they do'}
# {'user_id': 7, 'sentence': 'make no mistake the officers were assisting and supporting those peaceful protesters those snipers are terro'}
# {'user_id': 7, 'sentence': 'there was also girl and boy and another girl and several thousand other girls and boys'}
# {'user_id': 7, 'sentence': 'tried to feed my daughter winter squash and she gave me the lebron blocking curry face'}
# {'user_id': 7, 'sentence': 'one candidate might not move you forward but you know the other will set you back thats still choice'}
# {'user_id': 7, 'sentence': 'if pokemon uses psychic attacks and specialises in hunting ghost types im gon na call it psychic'}
# {'user_id': 7, 'sentence': 'lots of pressure tonight lebron james needs to win the championship for the space jam ending'}
# {'user_id': 7, 'sentence': 'anti gay pastor ken adkins who dressed in drag to protest homosexuality found guilty on child molestation charges'}
# {'user_id': 7, 'sentence': 'to fight college discrimination against whites so maybe later theyll be more competitive for white'}
# {'user_id': 7, 'sentence': 'kaepernick said he didnt vote because it was all the same thats what i was referring to in my tweet to him'}
# {'user_id': 7, 'sentence': 'that sucks good luck chuck make that exam regret getting in the way of your weekend plans'}
# {'user_id': 7, 'sentence': 'if people actually read this article and not just the click bait headline theyll also read that multiple studies have shown that the lockdowns have actually saved millions of lives and also comparing construed responses isnt an accurate measure'}
# {'user_id': 7, 'sentence': 'brazilian coach we need someone who can blind our opponents with his teeth firmino put me in coach'}
# {'user_id': 7, 'sentence': 'the day has arrived check out my new comedy special streaming now on'}
# {'user_id': 7, 'sentence': 'exhibit serial bombing terrorist exhibit an innocent child this is not objectivity the is in the bus'}
# {'user_id': 7, 'sentence': 'rep joe kennedy had some choice words for paul ryan about the gop health care bill'}
# {'user_id': 7, 'sentence': 'so last summer i randomly met this woman on words with friends we played games together and she actually ended'}
# {'user_id': 7, 'sentence': 'daily show writers share their favorite moments from the summer games'}
# {'user_id': 7, 'sentence': 'phoenix arizona is gon na be blast next week its my first time doing show out there'}
# {'user_id': 7, 'sentence': 'remind me senator are balls the things you had when trump destroyed you insulted your wifes face said your dad killed jfk hijacked your party and all you did was kiss his ass'}
# {'user_id': 7, 'sentence': 'give me your tired your poor your huddled masses yearning to breathe free as long as theyre'}

# %%
import torch.nn as nn
from transformers import BertTokenizer, BertForSequenceClassification
import torch.optim as optim

# %%
class BERT(nn.Module):
    
    def __init__(self):
        super(BERT, self).__init__()
        
        options_name = "bert_base-uncased"
        self.encoder = BertForSequenceClassification.from_pretrained(options_name)
    
    def forward(self, text, label):
        loss, text_fea = self.encoder(text, labels=label)[:2]
        
        return loss, text_fea

# %%
# Save and Load Functions

def save_checkpoint(save_path, model, valid_loss):

    if save_path == None:
        return
    
    state_dict = {'model_state_dict': model.state_dict(),
                  'valid_loss': valid_loss}
    
    torch.save(state_dict, save_path)
    print(f'Model saved to ==> {save_path}')

def load_checkpoint(load_path, model):
    
    if load_path==None:
        return
    
    state_dict = torch.load(load_path, map_location=device)
    print(f'Model loaded from <== {load_path}')
    
    model.load_state_dict(state_dict['model_state_dict'])
    return state_dict['valid_loss']


def save_metrics(save_path, train_loss_list, valid_loss_list, global_steps_list):

    if save_path == None:
        return
    
    state_dict = {'train_loss_list': train_loss_list,
                  'valid_loss_list': valid_loss_list,
                  'global_steps_list': global_steps_list}
    
    torch.save(state_dict, save_path)
    print(f'Model saved to ==> {save_path}')


def load_metrics(load_path):

    if load_path==None:
        return
    
    state_dict = torch.load(load_path, map_location=device)
    print(f'Model loaded from <== {load_path}')
    
    return state_dict['train_loss_list'], state_dict['valid_loss_list'], state_dict['global_steps_list']

# %%
# Training Function

def train(model,
          optimizer,
          criterion = nn.BCELoss(),
          train_loader = train_iter,
          valid_loader = valid_iter,
          num_epochs = 5,
          eval_every = len(train_iter) // 2,
          file_path = destination_folder,
          best_valid_loss = float("Inf")):
    
    # initialize running values
    running_loss = 0.0
    valid_running_loss = 0.0
    global_step = 0
    train_loss_list = []
    valid_loss_list = []
    global_steps_list = []

    # training loop
    model.train()
    for epoch in range(num_epochs):
        for (labels, title, text, titletext), _ in train_loader:
            labels = labels.type(torch.LongTensor)           
            labels = labels.to(device)
            titletext = titletext.type(torch.LongTensor)  
            titletext = titletext.to(device)
            output = model(titletext, labels)
            loss, _ = output

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # update running values
            running_loss += loss.item()
            global_step += 1

            # evaluation step
            if global_step % eval_every == 0:
                model.eval()
                with torch.no_grad():                    

                    # validation loop
                    for (labels, title, text, titletext), _ in valid_loader:
                        labels = labels.type(torch.LongTensor)           
                        labels = labels.to(device)
                        titletext = titletext.type(torch.LongTensor)  
                        titletext = titletext.to(device)
                        output = model(titletext, labels)
                        loss, _ = output
                        
                        valid_running_loss += loss.item()

                # evaluation
                average_train_loss = running_loss / eval_every
                average_valid_loss = valid_running_loss / len(valid_loader)
                train_loss_list.append(average_train_loss)
                valid_loss_list.append(average_valid_loss)
                global_steps_list.append(global_step)

                # resetting running values
                running_loss = 0.0                
                valid_running_loss = 0.0
                model.train()

                # print progress
                print('Epoch [{}/{}], Step [{}/{}], Train Loss: {:.4f}, Valid Loss: {:.4f}'
                      .format(epoch+1, num_epochs, global_step, num_epochs*len(train_loader),
                              average_train_loss, average_valid_loss))
                
                # checkpoint
                if best_valid_loss > average_valid_loss:
                    best_valid_loss = average_valid_loss
                    save_checkpoint(file_path + '/' + 'model.pt', model, best_valid_loss)
                    save_metrics(file_path + '/' + 'metrics.pt', train_loss_list, valid_loss_list, global_steps_list)
    
    save_metrics(file_path + '/' + 'metrics.pt', train_loss_list, valid_loss_list, global_steps_list)
    print('Finished Training!')

model = BERT().to(device)
optimizer = optim.Adam(model.parameters(), lr=2e-5)

train(model=model, optimizer=optimizer)
